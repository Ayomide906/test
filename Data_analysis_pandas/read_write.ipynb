# %%
import pandas as pd
df=pd.read_csv("stock_data.csv")
df
# Out:
#   Datasource: Google finance     Unnamed: 1 Unnamed: 2 Unnamed: 3  \
# 0                    tickers            eps    revenue      price
# 1                      GOOGL          27.82         87        845
# 2                        WMT           4.61        484         65
# 3                       MSFT             -1         85         64
# 4                       RIL   not available         50       1023
# 5                       TATA            5.6         -1       n.a.
#
#       Unnamed: 4
# 0         people
# 1     larry page
# 2           n.a.
# 3     bill gates
# 4  mukesh ambani
# 5     ratan tata

# %%
df=pd.read_csv("stock_data.csv",skiprows=1,names=["stock_symbol","eps","revenue","price","people"],na_values={"eps":["not available","n.a."],"price":["not available","n.a."],"people":["n.a."]}) # or use header=<row>
df
# Out:
#   stock_symbol    eps  revenue  price         people
# 0      tickers    eps  revenue  price         people
# 1        GOOGL  27.82       87    845     larry page
# 2          WMT   4.61      484     65            NaN
# 3         MSFT     -1       85     64     bill gates
# 4         RIL     NaN       50   1023  mukesh ambani
# 5         TATA    5.6       -1    NaN     ratan tata

# %%
df
# Out:
#   stock_symbol    eps  revenue  price      people
# 0      tickers    eps  revenue  price      people
# 1        GOOGL  27.82       87    845  larry page
