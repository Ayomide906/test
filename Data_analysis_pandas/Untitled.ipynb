# %% [markdown]
#               #statistics of imdb_rating using python

# %%
import csv
def calculate_rating_stats(data,industry=None):
    rating=[]
    for row in data:
        if (row[1]==industry or not industry) and row[3]!='NULL':
            rating.append(float(row[3]))
    max_rating=max(rating)
    min_rating=min(rating)
    avg_rating=round(sum(rating)/len(rating),2)
    return max_rating, min_rating, avg_rating
with open("movies.csv") as f:
    data=list(csv.reader(f))
    header=data[0]
    data=data[1:]
max_rating,min_rating,avg_rating=calculate_rating_stats(data)
print("All records: max_rating=",max_rating,",min_rating=",min_rating,", avg_rating=",avg_rating)
max_rating,min_rating,avg_rating=calculate_rating_stats(data,"Hollywood")
print("Hollywood: max_rating=",max_rating,",min_rating=",min_rating,", avg_rating=",avg_rating)
max_rating,min_rating,avg_rating=calculate_rating_stats(data,"Bollywood")
print("Bollywood: max_rating=",max_rating,",min_rating=",min_rating,", avg_rating=",avg_rating)
# Out:
# All records: max_rating= 9.3 ,min_rating= 1.9 , avg_rating= 7.92
# Hollywood: max_rating= 9.3 ,min_rating= 6.8 , avg_rating= 8.13
# Bollywood: max_rating= 8.4 ,min_rating= 1.9 , avg_rating= 7.66

# %% [markdown]
# #Option 2-Movies analysis using Pandas

# %%
import pandas as pd

df=pd.read_csv("movies.csv",dtype=None)
df.head()
# Out:
#                                          title   industry  release_year  \
# 0                              Pather Panchali  Bollywood          1955
# 1  Doctor Strange in the Multiverse of Madness  Hollywood          2022
# 2                        Thor: The Dark World   Hollywood          2013
# 3                              Thor: Ragnarok   Hollywood          2017
# 4                      Thor: Love and Thunder   Hollywood          2022
#
#    imdb_rating                     studio   budget   revenue       unit  \
# 0          8.3  Government of West Bengal  70000.0  100000.0  Thousands
# 1          7.0             Marvel Studios    200.0     954.8   Millions
# 2          6.8             Marvel Studios    165.0     644.8   Millions
# 3          7.9             Marvel Studios    180.0     854.0   Millions
# 4          6.8             Marvel Studios    250.0     670.0   Millions
#
#   currency language
# 0      INR  Bengali
# 1      USD  English
# 2      USD  English
# ...

# %%
df.tail()
# Out:
#                         title   industry  release_year  imdb_rating  \
# 32                  Shershaah  Bollywood          2021          8.4
# 33           K.G.F: Chapter 2  Bollywood          2022          8.4
# 34  Pushpa: The Rise - Part 1  Bollywood          2021          7.6
# 35                        RRR  Bollywood          2022          8.0
# 36   Baahubali: The Beginning  Bollywood          2015          8.0
#
#                  studio  budget  revenue      unit currency language
# 32   Dharma Productions   500.0    950.0  Millions      INR    Hindi
# 33        Hombale Films     1.0     12.5  Billions      INR  Kannada
# 34  Mythri Movie Makers     2.0      3.6  Billions      INR   Telugu
# 35    DVV Entertainment     5.5     12.0  Billions      INR   Telugu
# 36     Arka Media Works     1.8      6.5  Billions      INR   Telugu

# %%
df.sample(4)
# Out:
#                 title   industry  release_year  imdb_rating  \
# 33   K.G.F: Chapter 2  Bollywood          2022          8.4
# 17  Avengers: Endgame  Hollywood          2019          8.4
# 16           Parasite  Hollywood          2019          8.5
# 30  Bajrangi Bhaijaan  Bollywood          2015          8.1
#
#                studio  budget  revenue      unit currency language
# 33      Hombale Films     1.0     12.5  Billions      INR  Kannada
# 17     Marvel Studios   400.0   2798.0  Millions      USD  English
# 16                NaN    15.5    263.1  Millions      USD  English
# 30  Salman Khan Films   900.0  11690.0  Millions      INR    Hindi

# %%
df[2:6]
# Out:
#                       title   industry  release_year  imdb_rating  \
# 2     Thor: The Dark World   Hollywood          2013          6.8
# 3           Thor: Ragnarok   Hollywood          2017          7.9
# 4   Thor: Love and Thunder   Hollywood          2022          6.8
# 5  The Shawshank Redemption  Hollywood          1994          9.3
#
#                       studio  budget  revenue      unit currency language
# 2             Marvel Studios   165.0    644.8  Millions      USD  English
# 3             Marvel Studios   180.0    854.0  Millions      USD  English
# 4             Marvel Studios   250.0    670.0  Millions      USD  English
# 5  Castle Rock Entertainment    25.0     73.3  Millions      USD  English

# %%
df.shape
# Out:
# (37, 10)

# %%
df.imdb_rating.min(), df.imdb_rating.max(), df.imdb_rating.mean()
# Out:
# (np.float64(1.9), np.float64(9.3), np.float64(7.919444444444445))

# %%
df_b=df[df.industry=="Bollywood"]   #gives u a new dataframe selected by industry=bollywood
df_h=df[df.industry=="Hollywood"]

# %%
df_b.imdb_rating.min(),df_b.imdb_rating.max(),df_b.imdb_rating.mean()
# Out:
# (np.float64(1.9), np.float64(8.4), np.float64(7.656250000000001))

# %%
df_h.imdb_rating.min(),df_h.imdb_rating.max(),df_h.imdb_rating.mean()
# Out:
# (np.float64(6.8), np.float64(9.3), np.float64(8.130000000000003))

# %%
df.columns
# Out:
# Index(['title', 'industry', 'release_year', 'imdb_rating', 'studio', 'budget',
#        'revenue', 'unit', 'currency', 'language'],
#       dtype='object')

# %%
df.industry.unique()
# Out:
# array(['Bollywood', 'Hollywood'], dtype=object)

# %%
df.language.unique()
# Out:
# array(['Bengali', 'English', 'Hindi', 'Kannada', 'Telugu'], dtype=object)

# %%
s=[1,2,3,4,5,5,6,1,2,4]
p=set(s)
p
# Out:
# {1, 2, 3, 4, 5, 6}

# %%
df.industry.value_counts()
# Out:
# industry
# Hollywood    20
# Bollywood    17
# Name: count, dtype: int64

# %%
df.language.value_counts()
# Out:
# language
# English    20
# Hindi      12
# Telugu      3
# Bengali     1
# Kannada     1
# Name: count, dtype: int64

# %%
df.language
# Out:
# 0     Bengali
# 1     English
# 2     English
# 3     English
# 4     English
# 5     English
# 6     English
# 7     English
# 8     English
# 9     English
# 10    English
# 11    English
# 12    English
# 13    English
# 14    English
# 15    English
# 16    English
# 17    English
# 18    English
# 19    English
# 20    English
# 21      Hindi
# 22      Hindi
# 23      Hindi
# 24      Hindi
# 25      Hindi
# 26      Hindi
# 27      Hindi
# 28      Hindi
# 29      Hindi
# 30      Hindi
# 31      Hindi
# 32      Hindi
# 33    Kannada
# 34     Telugu
# 35     Telugu
# 36     Telugu
# Name: language, dtype: object

# %%
df_new=df[["industry","title","imdb_rating"]][df.industry=="Bollywood"] #for bollywood
df_new
# Out:
#      industry                        title  imdb_rating
# 0   Bollywood              Pather Panchali          8.3
# 21  Bollywood  Dilwale Dulhania Le Jayenge          8.0
# 22  Bollywood                     3 Idiots          8.4
# 23  Bollywood     Kabhi Khushi Kabhie Gham          7.4
# 24  Bollywood             Bajirao Mastani           7.2
# 25  Bollywood             Taare Zameen Par          8.3
# 26  Bollywood          Munna Bhai M.B.B.S.          8.1
# 27  Bollywood                           PK          8.1
# 28  Bollywood                        Sanju          NaN
# 29  Bollywood            The Kashmir Files          8.3
# 30  Bollywood            Bajrangi Bhaijaan          8.1
# 31  Bollywood                       Race 3          1.9
# 32  Bollywood                    Shershaah          8.4
# 33  Bollywood             K.G.F: Chapter 2          8.4
# 34  Bollywood    Pushpa: The Rise - Part 1          7.6
# 35  Bollywood                          RRR          8.0
# ...

# %%
df.columns
# Out:
# Index(['title', 'industry', 'release_year', 'imdb_rating', 'studio', 'budget',
#        'revenue', 'unit', 'currency', 'language'],
#       dtype='object')

# %%
df[(df.release_year>=2000) &(df.release_year<2010)]
# Out:
#                        title   industry  release_year  imdb_rating  \
# 7   The Pursuit of Happyness  Hollywood          2006          8.0
# 8                  Gladiator  Hollywood          2000          8.5
# 11                    Avatar  Hollywood          2009          7.8
# 13           The Dark Knight  Hollywood          2008          9.0
# 22                  3 Idiots  Bollywood          2009          8.4
# 23  Kabhi Khushi Kabhie Gham  Bollywood          2001          7.4
# 25          Taare Zameen Par  Bollywood          2007          8.3
# 26       Munna Bhai M.B.B.S.  Bollywood          2003          8.1
#
#                       studio  budget  revenue      unit currency language
# 7          Columbia Pictures    55.0    307.1  Millions      USD  English
# 8       Universal Pictures     103.0    460.5  Millions      USD  English
# 11          20th Century Fox   237.0   2847.0  Millions      USD  English
# ...

# %%
df.studio.unique()
# Out:
# array(['Government of West Bengal', 'Marvel Studios',
#        'Castle Rock Entertainment', 'Warner Bros. Pictures',
#        'Columbia Pictures', 'Universal Pictures  ', 'Paramount Pictures',
#        'Liberty Films', '20th Century Fox', 'Syncopy',
#        'Universal Pictures', nan, 'Yash Raj Films', 'Vinod Chopra Films',
#        'Dharma Productions', 'Vinod Chopra Productions', 'Zee Studios',
#        'Salman Khan Films', 'Hombale Films', 'Mythri Movie Makers',
#        'DVV Entertainment', 'Arka Media Works'], dtype=object)

# %%
df.describe()
# Out:
#        release_year  imdb_rating        budget        revenue
# count     37.000000    36.000000     37.000000      37.000000
# mean    2007.027027     7.919444   2084.975135    4117.135135
# std       17.657995     1.204947  11477.487145   16372.462682
# min     1946.000000     1.900000      1.000000       3.100000
# 25%     2001.000000     7.800000     15.500000     263.100000
# 50%     2014.000000     8.100000    165.000000     701.800000
# 75%     2018.000000     8.400000    250.000000    2000.000000
# max     2022.000000     9.300000  70000.000000  100000.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 37 entries, 0 to 36
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   title         37 non-null     object
#  1   industry      37 non-null     object
#  2   release_year  37 non-null     int64
#  3   imdb_rating   36 non-null     float64
#  4   studio        34 non-null     object
#  5   budget        37 non-null     float64
#  6   revenue       37 non-null     float64
#  7   unit          37 non-null     object
#  8   currency      37 non-null     object
#  9   language      37 non-null     object
# dtypes: float64(3), int64(1), object(6)
# memory usage: 3.0+ KB

# %%
df[(df.imdb_rating==df.imdb_rating.max())| (df.imdb_rating==df.imdb_rating.min())] #to print max and min
# Out:
#                        title   industry  release_year  imdb_rating  \
# 5   The Shawshank Redemption  Hollywood          1994          9.3
# 31                    Race 3  Bollywood          2018          1.9
#
#                        studio  budget  revenue      unit currency language
# 5   Castle Rock Entertainment    25.0     73.3  Millions      USD  English
# 31          Salman Khan Films     1.8      3.1  Billions      INR    Hindi

# %%
df["age"]=df["release_year"].apply(lambda x:2025-x) #to add a new column age by applying a function to column release_year
df.head()
# Out:
#                                          title   industry  release_year  \
# 0                              Pather Panchali  Bollywood          1955
# 1  Doctor Strange in the Multiverse of Madness  Hollywood          2022
# 2                        Thor: The Dark World   Hollywood          2013
# 3                              Thor: Ragnarok   Hollywood          2017
# 4                      Thor: Love and Thunder   Hollywood          2022
#
#    imdb_rating                     studio   budget   revenue       unit  \
# 0          8.3  Government of West Bengal  70000.0  100000.0  Thousands
# 1          7.0             Marvel Studios    200.0     954.8   Millions
# 2          6.8             Marvel Studios    165.0     644.8   Millions
# 3          7.9             Marvel Studios    180.0     854.0   Millions
# 4          6.8             Marvel Studios    250.0     670.0   Millions
#
#   currency language  age
# 0      INR  Bengali   70
# 1      USD  English    3
# ...

# %%
df["profit"]=df.apply(lambda x:x["revenue"]-x["budget"],axis=1) #the axis=1 indicate that each x is a row by doing that I can access any column x[]

# %%
df.head(4)
# Out:
#                                          title   industry  release_year  \
# 0                              Pather Panchali  Bollywood          1955
# 1  Doctor Strange in the Multiverse of Madness  Hollywood          2022
# 2                        Thor: The Dark World   Hollywood          2013
# 3                              Thor: Ragnarok   Hollywood          2017
#
#    imdb_rating                     studio   budget   revenue       unit  \
# 0          8.3  Government of West Bengal  70000.0  100000.0  Thousands
# 1          7.0             Marvel Studios    200.0     954.8   Millions
# 2          6.8             Marvel Studios    165.0     644.8   Millions
# 3          7.9             Marvel Studios    180.0     854.0   Millions
#
#   currency language  age   profit
# 0      INR  Bengali   70  30000.0
# 1      USD  English    3    754.8
# 2      USD  English   12    479.8
# 3      USD  English    8    674.0

# %%
df["units"]=df["revenue"].apply(lambda x: "Million" if x>=1000000 else "Thousand")

# %%
df
# Out:
#                                           title   industry  release_year  \
# 0                               Pather Panchali  Bollywood          1955
# 1   Doctor Strange in the Multiverse of Madness  Hollywood          2022
# 2                         Thor: The Dark World   Hollywood          2013
# 3                               Thor: Ragnarok   Hollywood          2017
# 4                       Thor: Love and Thunder   Hollywood          2022
# 5                      The Shawshank Redemption  Hollywood          1994
# 6                                  Interstellar  Hollywood          2014
# 7                      The Pursuit of Happyness  Hollywood          2006
# 8                                     Gladiator  Hollywood          2000
# 9                                       Titanic  Hollywood          1997
# 10                        It's a Wonderful Life  Hollywood          1946
# 11                                       Avatar  Hollywood          2009
# ...

# %%
df.drop("units",axis=1)
# Out:
#                                           title   industry  release_year  \
# 0                               Pather Panchali  Bollywood          1955
# 1   Doctor Strange in the Multiverse of Madness  Hollywood          2022
# 2                         Thor: The Dark World   Hollywood          2013
# 3                               Thor: Ragnarok   Hollywood          2017
# 4                       Thor: Love and Thunder   Hollywood          2022
# 5                      The Shawshank Redemption  Hollywood          1994
# 6                                  Interstellar  Hollywood          2014
# 7                      The Pursuit of Happyness  Hollywood          2006
# 8                                     Gladiator  Hollywood          2000
# 9                                       Titanic  Hollywood          1997
# 10                        It's a Wonderful Life  Hollywood          1946
# 11                                       Avatar  Hollywood          2009
# ...

# %%
df
# Out:
#                                           title   industry  release_year  \
# 0                               Pather Panchali  Bollywood          1955
# 1   Doctor Strange in the Multiverse of Madness  Hollywood          2022
# 2                         Thor: The Dark World   Hollywood          2013
# 3                               Thor: Ragnarok   Hollywood          2017
# 4                       Thor: Love and Thunder   Hollywood          2022
# 5                      The Shawshank Redemption  Hollywood          1994
# 6                                  Interstellar  Hollywood          2014
# 7                      The Pursuit of Happyness  Hollywood          2006
# 8                                     Gladiator  Hollywood          2000
# 9                                       Titanic  Hollywood          1997
# 10                        It's a Wonderful Life  Hollywood          1946
# 11                                       Avatar  Hollywood          2009
# ...

# %%
df.drop("units",axis=1,inplace=True)

# %%
df
# Out:
#                                           title   industry  release_year  \
# 0                               Pather Panchali  Bollywood          1955
# 1   Doctor Strange in the Multiverse of Madness  Hollywood          2022
# 2                         Thor: The Dark World   Hollywood          2013
# 3                               Thor: Ragnarok   Hollywood          2017
# 4                       Thor: Love and Thunder   Hollywood          2022
# 5                      The Shawshank Redemption  Hollywood          1994
# 6                                  Interstellar  Hollywood          2014
# 7                      The Pursuit of Happyness  Hollywood          2006
# 8                                     Gladiator  Hollywood          2000
# 9                                       Titanic  Hollywood          1997
# 10                        It's a Wonderful Life  Hollywood          1946
# 11                                       Avatar  Hollywood          2009
# ...

# %%
df["industry"][df.unit=="Millions"].value_counts()
# Out:
# industry
# Hollywood    20
# Bollywood     9
# Name: count, dtype: int64

# %%
df.set_index("title",inplace=True) #title has to be set as index and inplaced so i can locate information of specific title
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_7336\1422560139.py in ?()
# ----> 1 df.set_index("title",inplace=True) #title has to be set as index and inplaced so i can locate information of specific title
#
# ~\AppData\Roaming\Python\Python313\site-packages\pandas\core\frame.py in ?(self, keys, drop, append, inplace, verify_integrity)
#    6125                     if not found:
#    6126                         missing.append(col)
#    6127
#    6128         if missing:
# -> 6129             raise KeyError(f"None of {missing} are in the columns")
#    6130
#    6131         if inplace:
#    6132             frame = self
#
# KeyError: "None of ['title'] are in the columns"

# %%
df.loc["Pather Panchali"]
# Out:
# industry                        Bollywood
# release_year                         1955
# imdb_rating                           8.3
# studio          Government of West Bengal
# budget                            70000.0
# revenue                          100000.0
# unit                            Thousands
# currency                              INR
# language                          Bengali
# Name: Pather Panchali, dtype: object

# %%
df.loc[["Pather Panchali","Doctor Strange in the Multiverse of Madness"]]
# Out:
#                                               industry  release_year  \
# title
# Pather Panchali                              Bollywood          1955
# Doctor Strange in the Multiverse of Madness  Hollywood          2022
#
#                                              imdb_rating  \
# title
# Pather Panchali                                      8.3
# Doctor Strange in the Multiverse of Madness          7.0
#
#                                                                 studio  \
# title
# Pather Panchali                              Government of West Bengal
# Doctor Strange in the Multiverse of Madness             Marvel Studios
#
#                                               budget   revenue       unit  \
# title
# Pather Panchali                              70000.0  100000.0  Thousands
# Doctor Strange in the Multiverse of Madness    200.0     954.8   Millions
#
#                                             currency language
# title
# ...

# %%
df.iloc[0]
# Out:
# industry                        Bollywood
# release_year                         1955
# imdb_rating                           8.3
# studio          Government of West Bengal
# budget                            70000.0
# revenue                          100000.0
# unit                            Thousands
# currency                              INR
# language                          Bengali
# Name: Pather Panchali, dtype: object

# %%
df.iloc[2:7]
# Out:
#                            industry  release_year  imdb_rating  \
# title
# Thor: The Dark World      Hollywood          2013          6.8
# Thor: Ragnarok            Hollywood          2017          7.9
# Thor: Love and Thunder    Hollywood          2022          6.8
# The Shawshank Redemption  Hollywood          1994          9.3
# Interstellar              Hollywood          2014          8.6
#
#                                              studio  budget  revenue  \
# title
# Thor: The Dark World                 Marvel Studios   165.0    644.8
# Thor: Ragnarok                       Marvel Studios   180.0    854.0
# Thor: Love and Thunder               Marvel Studios   250.0    670.0
# The Shawshank Redemption  Castle Rock Entertainment    25.0     73.3
# Interstellar                  Warner Bros. Pictures   165.0    701.8
#
#                               unit currency language
# title
# Thor: The Dark World      Millions      USD  English
# ...

# %%
df.reset_index[inplace=True]
# Out:
#   Cell In[23], line 1
#     df.reset_index[inplace=True]
#                    ^
# SyntaxError: invalid syntax. Maybe you meant '==' or ':=' instead of '='?

# %%
df.reset_index(inplace=True)

# %%
df
# Out:
#                                           title   industry  release_year  \
# 0                               Pather Panchali  Bollywood          1955
# 1   Doctor Strange in the Multiverse of Madness  Hollywood          2022
# 2                         Thor: The Dark World   Hollywood          2013
# 3                               Thor: Ragnarok   Hollywood          2017
# 4                       Thor: Love and Thunder   Hollywood          2022
# 5                      The Shawshank Redemption  Hollywood          1994
# 6                                  Interstellar  Hollywood          2014
# 7                      The Pursuit of Happyness  Hollywood          2006
# 8                                     Gladiator  Hollywood          2000
# 9                                       Titanic  Hollywood          1997
# 10                        It's a Wonderful Life  Hollywood          1946
# 11                                       Avatar  Hollywood          2009
# ...
