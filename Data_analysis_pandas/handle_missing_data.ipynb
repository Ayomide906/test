# %%
import pandas as pd
df=pd.read_csv("datasets/weather_data.csv",parse_dates=["day"])
df
# Out:
#          day  temperature  windspeed   event
# 0 2017-01-01         32.0        6.0    Rain
# 1 2017-01-04          NaN        9.0   Sunny
# 2 2017-01-05         28.0        NaN    Snow
# 3 2017-01-06          NaN        7.0     NaN
# 4 2017-01-07         32.0        NaN    Rain
# 5 2017-01-08          NaN        NaN   Sunny
# 6 2017-01-09          NaN        NaN     NaN
# 7 2017-01-10         34.1        8.1  Cloudy
# 8 2017-01-11         40.0       12.0   Sunny

# %%
type(df.day)
# Out:
# pandas.core.series.Series

# %%
df
# Out:
#          day  temperature  windspeed   event
# 0 2017-01-01         32.0        6.0    Rain
# 1 2017-01-04          NaN        9.0   Sunny
# 2 2017-01-05         28.0        NaN    Snow
# 3 2017-01-06          NaN        7.0     NaN
# 4 2017-01-07         32.0        NaN    Rain
# 5 2017-01-08          NaN        NaN   Sunny
# 6 2017-01-09          NaN        NaN     NaN
# 7 2017-01-10         34.1        8.1  Cloudy
# 8 2017-01-11         40.0       12.0   Sunny

# %%
df.fillna(0)   #to fill empty cells or na cells
# Out:
#          day  temperature  windspeed   event
# 0 2017-01-01         32.0        6.0    Rain
# 1 2017-01-04          0.0        9.0   Sunny
# 2 2017-01-05         28.0        0.0    Snow
# 3 2017-01-06          0.0        7.0       0
# 4 2017-01-07         32.0        0.0    Rain
# 5 2017-01-08          0.0        0.0   Sunny
# 6 2017-01-09          0.0        0.0       0
# 7 2017-01-10         34.1        8.1  Cloudy
# 8 2017-01-11         40.0       12.0   Sunny

# %%
df
# Out:
#          day  temperature  windspeed   event
# 0 2017-01-01         32.0        6.0    Rain
# 1 2017-01-04          NaN        9.0   Sunny
# 2 2017-01-05         28.0        NaN    Snow
# 3 2017-01-06          NaN        7.0     NaN
# 4 2017-01-07         32.0        NaN    Rain
# 5 2017-01-08          NaN        NaN   Sunny
# 6 2017-01-09          NaN        NaN     NaN
# 7 2017-01-10         34.1        8.1  Cloudy
# 8 2017-01-11         40.0       12.0   Sunny

# %%
df.fillna({"temperature":df.temperature.mean(),
           "windspeed":df.windspeed.mean(),
           "event":"No event"})
# Out:
#          day  temperature  windspeed     event
# 0 2017-01-01        32.00       6.00      Rain
# 1 2017-01-04        33.22       9.00     Sunny
# 2 2017-01-05        28.00       8.42      Snow
# 3 2017-01-06        33.22       7.00  No event
# 4 2017-01-07        32.00       8.42      Rain
# 5 2017-01-08        33.22       8.42     Sunny
# 6 2017-01-09        33.22       8.42  No event
# 7 2017-01-10        34.10       8.10    Cloudy
# 8 2017-01-11        40.00      12.00     Sunny

# %%
df.ffill(limit=1)
# Out:
#          day  temperature  windspeed   event
# 0 2017-01-01         32.0        6.0    Rain
# 1 2017-01-04         32.0        9.0   Sunny
# 2 2017-01-05         28.0        9.0    Snow
# 3 2017-01-06         28.0        7.0    Snow
# 4 2017-01-07         32.0        7.0    Rain
# 5 2017-01-08         32.0        NaN   Sunny
# 6 2017-01-09          NaN        NaN   Sunny
# 7 2017-01-10         34.1        8.1  Cloudy
# 8 2017-01-11         40.0       12.0   Sunny

# %%
df.infer_objects(copy=False)  #to interpolate
df.interpolate()
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_12668\1696104357.py:2: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   df.interpolate()
#          day  temperature  windspeed   event
# 0 2017-01-01         32.0      6.000    Rain
# 1 2017-01-04         30.0      9.000   Sunny
# 2 2017-01-05         28.0      8.000    Snow
# 3 2017-01-06         30.0      7.000     NaN
# 4 2017-01-07         32.0      7.275    Rain
# 5 2017-01-08         32.7      7.550   Sunny
# 6 2017-01-09         33.4      7.825     NaN
# 7 2017-01-10         34.1      8.100  Cloudy
# 8 2017-01-11         40.0     12.000   Sunny

# %%
df.dropna(how="all") #specifying all means you wanna drop data only when all column is none
# Out:
#          day  temperature  windspeed   event
# 0 2017-01-01         32.0        6.0    Rain
# 1 2017-01-04          NaN        9.0   Sunny
# 2 2017-01-05         28.0        NaN    Snow
# 3 2017-01-06          NaN        7.0     NaN
# 4 2017-01-07         32.0        NaN    Rain
# 5 2017-01-08          NaN        NaN   Sunny
# 6 2017-01-09          NaN        NaN     NaN
# 7 2017-01-10         34.1        8.1  Cloudy
# 8 2017-01-11         40.0       12.0   Sunny

# %%
df
# Out:
#             temperature  windspeed   event
# day
# 2017-01-01         32.0        6.0    Rain
# 2017-01-04          NaN        9.0   Sunny
# 2017-01-05         28.0        NaN    Snow
# 2017-01-06          NaN        7.0     NaN
# 2017-01-07         32.0        NaN    Rain
# 2017-01-08          NaN        NaN   Sunny
# 2017-01-09          NaN        NaN     NaN
# 2017-01-10         34.1        8.1  Cloudy
# 2017-01-11         40.0       12.0   Sunny

# %%
df.dropna(thresh=2) #will remove when na =2 or above
# Out:
#             temperature  windspeed   event
# day
# 2017-01-01         32.0        6.0    Rain
# 2017-01-04          NaN        9.0   Sunny
# 2017-01-05         28.0        NaN    Snow
# 2017-01-07         32.0        NaN    Rain
# 2017-01-10         34.1        8.1  Cloudy
# 2017-01-11         40.0       12.0   Sunny

# %%
df
# Out:
#             temperature  windspeed   event
# day
# 2017-01-01         32.0        6.0    Rain
# 2017-01-04          NaN        9.0   Sunny
# 2017-01-05         28.0        NaN    Snow
# 2017-01-06          NaN        7.0     NaN
# 2017-01-07         32.0        NaN    Rain
# 2017-01-08          NaN        NaN   Sunny
# 2017-01-09          NaN        NaN     NaN
# 2017-01-10         34.1        8.1  Cloudy
# 2017-01-11         40.0       12.0   Sunny

# %%
new_df=df.fillna({x:-99999 for x in df.columns if x !="event"}|{"event":"no event"})
new_df   #to fill all na values wih -99999 except event column
# Out:
#             temperature  windspeed     event
# day
# 2017-01-01         32.0        6.0      Rain
# 2017-01-04     -99999.0        9.0     Sunny
# 2017-01-05         28.0   -99999.0      Snow
# 2017-01-06     -99999.0        7.0  no event
# 2017-01-07         32.0   -99999.0      Rain
# 2017-01-08     -99999.0   -99999.0     Sunny
# 2017-01-09     -99999.0   -99999.0  no event
# 2017-01-10         34.1        8.1    Cloudy
# 2017-01-11         40.0       12.0     Sunny

# %%
import numpy as np
new_df.replace(to_replace=[-99999,"no event"],value=np.nan) #the to_replace and value is not really necessary though
# Out:
#             temperature  windspeed   event
# day
# 2017-01-01         32.0        6.0    Rain
# 2017-01-04          NaN        9.0   Sunny
# 2017-01-05         28.0        NaN    Snow
# 2017-01-06          NaN        7.0     NaN
# 2017-01-07         32.0        NaN    Rain
# 2017-01-08          NaN        NaN   Sunny
# 2017-01-09          NaN        NaN     NaN
# 2017-01-10         34.1        8.1  Cloudy
# 2017-01-11         40.0       12.0   Sunny

# %%
new_df=df.fillna({x:-99999 for x in df.columns if x !="event"}|{"event":"no event"})
new_df   #to fill all na values wih -99999 except event column
# Out:
#             temperature  windspeed     event
# day
# 2017-01-01         32.0        6.0      Rain
# 2017-01-04     -99999.0        9.0     Sunny
# 2017-01-05         28.0   -99999.0      Snow
# 2017-01-06     -99999.0        7.0  no event
# 2017-01-07         32.0   -99999.0      Rain
# 2017-01-08     -99999.0   -99999.0     Sunny
# 2017-01-09     -99999.0   -99999.0  no event
# 2017-01-10         34.1        8.1    Cloudy
# 2017-01-11         40.0       12.0     Sunny

# %%
df.replace({x:-99999 for x in df.columns if x !="event"}|{"event":"no event"},value=np.nan)
# Out:
#             temperature  windspeed   event
# day
# 2017-01-01         32.0        6.0    Rain
# 2017-01-04          NaN        9.0   Sunny
# 2017-01-05         28.0        NaN    Snow
# 2017-01-06          NaN        7.0     NaN
# 2017-01-07         32.0        NaN    Rain
# 2017-01-08          NaN        NaN   Sunny
# 2017-01-09          NaN        NaN     NaN
# 2017-01-10         34.1        8.1  Cloudy
# 2017-01-11         40.0       12.0   Sunny

# %%
new_df.replace({-99999:np.nan,    #key,value=old,new
           "no event":"Sunny"})
# Out:
#             temperature  windspeed   event
# day
# 2017-01-01         32.0        6.0    Rain
# 2017-01-04          NaN        9.0   Sunny
# 2017-01-05         28.0        NaN    Snow
# 2017-01-06          NaN        7.0   Sunny
# 2017-01-07         32.0        NaN    Rain
# 2017-01-08          NaN        NaN   Sunny
# 2017-01-09          NaN        NaN   Sunny
# 2017-01-10         34.1        8.1  Cloudy
# 2017-01-11         40.0       12.0   Sunny
