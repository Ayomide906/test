# %%
pip install seaborn
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.3.1 -> 25.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd
df_sales =pd.read_excel("8_matplotlib_seaborn/linechart.xlsx")
df_sales.head()
# Out:
#    Quarter  Fridge  Dishwasher  Washing Machine
# 0  Q1 2022    12.5         8.0              9.2
# 1  Q2 2022    11.0         7.5              8.5
# 2  Q3 2022    13.2         9.0              7.5
# 3  Q4 2022    16.4        11.0              7.6
# 4  Q1 2023    13.8         9.5              6.8

# %%
from matplotlib import pyplot as plt
plt.figure(figsize=(12,4))
plt.plot(df_sales["Quarter"],df_sales["Fridge"],color='blue',label="Fridge")
plt.plot(df_sales["Quarter"],df_sales["Dishwasher"],color='green',label="Dishwasher")
plt.plot(df_sales["Quarter"],df_sales["Washing Machine"],color='orange',label="washing machine")
plt.title("Product Sales")
plt.ylabel("Revenue (min $)")
plt.xlabel("Financial Quarter")
plt.legend() #this will create a fine label
plt.show()

# %%
total_sales=df_sales[["Fridge","Dishwasher","Washing Machine"]].sum()
total_sales.index
# Out:
# Index(['Fridge', 'Dishwasher', 'Washing Machine'], dtype='object')

# %% [markdown]
# <h2 style="color:#001f3f; font-size:32px;">Pie Chart</h2>

# %%
plt.pie(total_sales,labels=total_sales.index,colors=["green","blue","orange"],autopct="%1.1f%%",explode=(0.1,0,0),shadow=True,
       startangle=140)    #the labels is passed as a list
plt.show()

# %% [markdown]
# <h2 style="color:#001f3f, font-size:32px;">Bar Chart</h2>

# %%
df_sales.plot(kind="bar",x="Quarter")
plt.xticks(rotation=45)
plt.title("sale analysis quarterly")
# Out:
# Text(0.5, 1.0, 'sale analysis quarterly')

# %% [markdown]
# <h2 style="color:black; font:32px">Histogram</h2>

# %%
df_score=pd.read_excel("8_matplotlib_seaborn/histograms.xlsx")
df_score.head()
# Out:
#        Name  Exam_Score
# 0     Aarav          45
# 1   Michael          71
# 2     Bilal          59
# 3  Priyanka          92
# 4    Sophia           0

# %%
plt.hist(df_score['Exam_Score'])
# Out:
# (array([2., 0., 1., 0., 3., 5., 4., 4., 6., 5.]),
#  array([ 0. ,  9.5, 19. , 28.5, 38. , 47.5, 57. , 66.5, 76. , 85.5, 95. ]),
#  <BarContainer object of 10 artists>)

# %%
import seaborn as sns
sns.histplot(df_score["Exam_Score"],kde=True)  #kde=True will plot the population density
plt.xlabel("Score")
plt.ylabel("Frequency")
plt.title("Exam Scores Distribution")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[27], line 2
#       1 import seaborn as sns
# ----> 2 sns.histplot(df_score["Exam_Score"],kde=True)  #kde=True will plot the population density
#       3 plt.xlabel("Score")
#       4 plt.ylabel("Frequency")
#
# NameError: name 'df_score' is not defined

# %%
df=pd.read_excel("8_matplotlib_seaborn/scatter_plot.xlsx")
df
# Out:
#    area_square_ft  price
# 0             650     55
# 1             800     91
# 2             950     96
# 3            1100    122
# 4             500     34
# 5            1200    120
# 6             700     95
# 7             850    110
# 8            1000    115
# 9            1150     41

# %%
sns.scatterplot(data=df,x="area_square_ft",y="price")
# Out:
# <Axes: xlabel='area_square_ft', ylabel='price'>

# %% [markdown]
# <h2 style="color:black; font-value:32px">Scatter Plot with many variables</h2>

# %%
df_long = df_sales.melt(id_vars="Quarter", 
                        value_vars=["Fridge", "Dishwasher", "Washing Machine"],
                        var_name="Appliance", 
                        value_name="Sales")
sns.scatterplot(data=df_long, x="Quarter", y="Sales", hue="Appliance")

# Optional: improve layout
plt.title("Sales by Appliance Over Quarters")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
df=pd.read_csv("C:/Users/user/Downloads/kaggle_diabetes.csv")
df.head()
df[df.Glucose==0]
df.replace({"Glucose":0},df.Glucose.mean(),inplace=True)
df[df.Glucose==0]
q3=df.Age.quantile(0.75)
q1=df.Age.quantile(0.25)
df[df.Age> q3+(1.5*q3-q1)]
# Out:
#       Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 459             9    134.0             74             33       60  25.9
# 929             9    134.0             74             33       60  25.9
# 1518            9    134.0             74             33       60  25.9
#
#       DiabetesPedigreeFunction  Age  Outcome
# 459                       0.46   81        0
# 929                       0.46   81        0
# 1518                      0.46   81        0

# %%
df.columns
# Out:
# Index(['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin',
#        'BMI', 'DiabetesPedigreeFunction', 'Age', 'Outcome'],
#       dtype='object')

# %%
plt.plot()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[30], line 2
#       1 sns.scatterplot(data=df,x="Glucose",y="BMI")
# ----> 2 plt.show()
#
# NameError: name 'plt' is not defined

# %%
sns.histplot(df["BloodPressure"],kde=True)
# Out:
# <Axes: xlabel='BloodPressure', ylabel='Count'>
